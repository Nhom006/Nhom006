# %% [markdown]
# <a href="https://colab.research.google.com/github/Nhom006/Nhom006/blob/main/Tao_bien.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tảo biển**
#
#
# Tảo biển sinh sản rất nhanh khi có môi trường thuận lợi với chúng và có những loài còn tiết ra môi trường những chất độc hại.
#
# Một loại tảo nâu trong môi trường nước bị ô nhiễm nặng sinh sản theo quy luật sau:
#
# Ngày đầu tiên (ngày 0) có n cá thể ở mức 1,
# Ở mỗi ngày tiếp theo, mỗi cá thể mức i sinh ra i cá thể mức 1, các cá thể mới sinh sẽ sinh sôi, phát triển từ ngày hôm sau.
# Bản thân các cá thể mức i phát triển thành mức i+1 và chu kỳ phát triển trong ngày chấm dứt.
# Hãy xác định sau k ngày trong nước biển có bao nhiêu cá thể.
#
# Dữ liệu: Vào từ thiết bị nhập chuẩn gồm một dòng chứa 2 số nguyên n và k (1 ≤ n ≤ 1000, 1 ≤ k ≤ 1017 ).
#
# Kết quả: Đưa ra thiết bị xuất chuẩn một số nguyên – số lượng cá thể tảo theo mô đun 109 + 7
#
# Ví dụ:
#
# INPUT: 3 2
#
# OUTPUT: 15
#
# ---
#
# # **Abstraction.**
#
# Cho 2 số nguyên n và k (1 ≤ n ≤ 1000, 1 ≤ k ≤ 1017 ), hãy tính (n * Fibonacci(2k + 1) % (10^9 + 7)).
#
# # **Pattern recognition.**
#
# - Dạng bài toán quy hoạch động.
# - Đặc điểm nhận dạng:
#
# Dựa vào đề bài, ta lập một bảng thống kê kết quả như sau:
#
# ![Capture.PNG](data:image/png;base64,...)
#
# Từ kết quả bảng trên, ta nhận thấy đây là một phần của dãy Fibonacci:
#
# ![Capture1.PNG](data:image/png;base64,...)
#
# Từ 2 bảng trên, ta thấy kết quả của bảng 1 ở ngày thứ k sẽ bằng kết quả ở mốc 2k+1 của bảng 2.
#
# # **Algorithm designed.**
#
# ![Capture3.PNG](data:image/png;base64,...)
#
# # **Độ phức tạp thuật toán.**
#
# - Nếu 2k + 1 > 2, ta cần duyệt từ 2 đến k - 1 để thực hiện 2 phép toán. Vì vậy độ phức tạp của thuật toán này là O(N).
#
# # **Programming.**
#
#
#
# ```
# n, k = [int(i) for i in input().split()]
# def fibo(x):
#   if x==1 or x==2:
#     return 1
#   else:
#     a = 1
#     b = 1
#     for i in range(2, x):
#       c = a + b
#       a = b
#       b = c
#     return b
# print(n*fibo(2*k+1) % (10**9+7))
#
# ```
